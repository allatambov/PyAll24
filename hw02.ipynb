# %% [markdown]
# # Программирование для всех (основы Python)
#
# *Алла Тамбовцева*
#
# ## Домашнее задание №2
#
# В качестве решения необходимо загрузить ipynb-файл с добавленным кодом (и ответами на вопросы, где требуется текстовый ответ или интерпретация результатов) на Dropbox. Ответы на вопросы без приведённого и корректно работающего кода Python не засчитываются.
#
# ## Описание
#
# Домашнее задание состоит из двух связанных между собой частей:
#
# * обработка и описание результатов опроса, сохранённых в файле Excel (15 баллов);
# * выгрузка данных из HTML-страницы (10 баллов).
#
# **Первая часть** предполагает работу с результатами опроса студентов Вышки, в ходе которого респондентам предлагалось выбрать наиболее интересных героев музыкальной сказки «Не покидай...» 1989 года на основе следующей информации:
#
# * по предложенному текстовому описанию (как в пьесах, без подробностей, намекающих на развитие сюжета);
# * по предложенным кадрам из фильма (актёры в образе героев в разных ситуациях).
#
# По итогам опроса фиксировалось следующее: выбор героев по текстовому описанию (не более двух героев), итоговый выбор героев после ознакомления с кадрами из фильма (не более двух героев), лайки/дизлайки представленным образам героев. Ознакомиться с опросником, чтобы быть более погружённым в контекст задания, можно по [ссылке](https://forms.gle/QYrjjKJj8k3BSkYa8).
#
# Во **второй части** предлагается выгрузить информацию о героях и актёрах этой сказки, включая число лайков и дизлайков, поставленных актёрам в образе героев этого фильма зарегистрированными пользователями сайта.

# %% [markdown]
# ## Часть 1. Обработка данных (15 баллов)
#
# В файле `NPK_24_25.xlsx` (скачать [здесь](https://github.com/allatambov/PyAll24/blob/main/NPK_24_25.xlsx)) сохранены результаты опроса, описанного в начале этого файла:
#
# * лист `описание`: выбор героев по текстовому описанию;
# * лист `лайки`: лайки/дизлайки, поставленные на основе кадров;
# * лист `итоговый выбор`: итоговый выбор героев.
#
# Таблицы на всех листах обладают одинаковой структурой, в первых столбцах зафиксирован профиль обучения респондентов, уровень обучения, пол. В столбцах с именами основных героев сохранены бинарные индикаторы, отражающие факт выбора героя на разных этапах опроса:
#
# * в таблицах `описание` и `итоговый выбор` значение 1 означает, что респондент проголосовал за героя, то есть выбрал его как интересного (можно было выбрать не более двух);
#
# * в таблице `лайки` значение 1 соответствует лайку, значение 0 – дизлайку.

# %% [markdown]
# ### Задача 1 (1 балл)
#
# Используя файл `NPK_24_25.xlsx`, загрузите в Python:
#
# * данные с листа `описание` и сохраните их в датафрейм `text`;
# * данные с листа `лайки` и сохраните их в датафрейм `visual`;
# * данные с листа `итоговый выбор` и сохраните их в датафрейм `final`.
#
# **Подсказка:** у функции `read_excel()` есть аргумент `sheet_name`, в него можно вписать название листа в виде строки с текстом или индекс листа в виде целого числа.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (1 балл)
#
# Выведите описательные статистики для всех *текстовых* столбцов в датафрейме `text` и ответьте на следующие вопросы:
#
# * студентов какого пола в выборке больше?
# * студентов какого профиля в выборке больше?
#
# Ответы на вопросы приведите в виде ячейки с текстом или в виде комментарив к коду.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (1 балл)
#
# Для каждого датафрейма (`text`, `visual`, `final`) выведите описательные статистики для всех *числовых* столбцов. Так как числовые столбцы с именами героев все бинарные (состоящие из 0 и 1), среднее по каждому столбцу – это доля единиц, то есть доля респондентов, выбравших героя или поставивших ему лайк по кадру.
#
# Пользуясь этим фактом, ответьте на следующие вопросы:
#
# * какой герой получил больше всего голосов по текстовому описанию?
# * какой образ героя, представленный актером/актрисой, получил больше всего лайков?
# * у какого героя больше всего голосов при итоговом выборе?
#
# Ответы на вопросы приведите в виде ячейки с текстом или в виде комментарив к коду.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (3 балла)
#
# **4.1.** Используя датафрейм `text` с выбором героев по текстовому описанию (назовём это выбором архетипов), выберите строки, соответствующие студентам, участвующих в следующих сериях опроса (столбец `опрос`):
#
# * `3` – 2 курс ОП «Бизнес-информатика» (Пермь), `10` – 2 курс ОП «Программная инженерия» (Пермь);
# * `4`, `8`, `9` – бакалавры ОП «Политология» (Москва), разные годы;
# * `7` – слушатели нашего курса в прошлом году, разные программы.
#
# Сохраните отобранные строки (для серий 3, 10, 4, 8, 9, 7) в новый датафрейм.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# **4.2.** Из датафрейма, созданного в предыдущем пункте, выберите столбцы с именами всех героев (с Теодора по Марселлу включительно) и сохраните их в отдельный датафрейм `text_ans`. В датафрейме `text_ans` должно быть 10 бинарных столбцов.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# **4.3.** Вычислите сумму по каждому столбцу в `text_ans`. Отсортируйте полученные результаты по полученной сумме.
#
# **Подсказка:** метод `.sum()` можно применять не только к отдельным столбцам, но и сразу ко всему датафрейму, для сортировки полученных результатов используйте метод `.sort_values()`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5 (2 балла)
#
# Добавьте в исходный датафрейм `text` (датафрейм из предыдущего задания уже не нужен):
#
# * бинарный столбец `Давиль-Оттилия`, где 1 ставится, если студент выбрал Давиля или Оттилию (значения 1 в соответствующих столбцах);
#
# * бинарный столбец `Жак-Марта`, где 1 ставится, если студент выбрал Жака или Марту (значения 1 в соответствующих столбцах);
#
# **Подсказка:** вспомните объединение условий и метод `.astype()`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6 (3 балла)
#
# Добавьте в исходный датафрейм `text` столбец `профиль2` со следующими значениями:
#
# * `социально-экономический`, если в профиле указаны значения `политология и управление`, `право и экономика`;
# * `информационно-математический`, если в профиле указано значение `математика и информатика`;
# * `другое`, если иное.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 7 (2 балла)
#
# Сгруппируйте строки по столбцу `профиль2` и для каждого профиля вычислите суммы по следующим столбцам:
# `Теодор`, `Флора`, `Альбина`, `Патрик`, `Марселла`, `Пенапью`, `Давиль`, `Оттилия`, `Жак`, `Марта`.
#
# Проинтепретируйте полученные результаты в контексте ответа на следующий вопрос: можно ли считать, что предпочтения героев различаются у студентов разных профилей? Если есть время, помимо формального ответа на вопрос можете поделиться мыслями на эту тему :)

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 8* (2 балла)
#
# Представьте, что вам необходимо выяснить, кто из героев «перетянул» на себя больше голосов после второго этапа опроса с просмотром кадров. Напишите код, который возвращает перечень с именами героев и числом «перетянутых» или «потерянных» голосов, то есть определяет разницу между суммой голосов в датафрейме `final` и суммой голосов в датафрейме `text` по каждому герою.
#
# Пример для понимания формата ожидаемого результата (значения и порядок могут быть другими, это результаты по одной из подвыборок):
#
#     Оттилия   9
#     Патрик   6
#     Марселла  1
#     Жак      0
#     Пенапью   0
#     Теодор    0
#     Марта    -1
#     Давиль   -3
#     Флора    -6
#     Альбина  -7
#     dtype: int64

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ## Часть 2. Парсинг HTML (10 баллов)

# %% [markdown]
# *Ключевые задачи этой части сопровождаются автоматическими тестами через конструкции с `assert`. Обращайте внимание на названия функций и типы объектов, которые требуются в условии задач.*

# %% [markdown]
# Дана страница с описанием фильма «Не покидай...» на сайте КИНО-ТЕАТР.РУ. Ссылка на главную страницу фильма сохранена с переменной `main`, ссылка на страницу с актёрами – в переменной `titr`.

# %%
main = "https://www.kino-teatr.ru/kino/movie/sov/4319/annot/"
titr = "https://www.kino-teatr.ru/kino/movie/sov/4319/titr/"

# %% [markdown]
# Если вдруг возникают проблемы с доступом (при парсинге выдается не исходный код страницы, а пустая страница с сообщением о попытках автоматического подключения к странице), можете воспользоваться запасными ссылками `main` и `titr`, это ссылки на копии страниц в репозитории Github для нашего курса, они точно открываются.

# %%
# запасные ссылки
main = "https://raw.githubusercontent.com/allatambov/PyAll24/refs/heads/main/annot.html"
titr = "https://raw.githubusercontent.com/allatambov/PyAll24/refs/heads/main/titr.html"

# %% [markdown]
# ### Задача 0 (2 балла)
#
# Используя возможности библиотек `requests` и `BeautifulSoup`, извлеките из страницы (ссылка в `main`) название фильма (можно вместе с годом) и его рейтинг. Сохраните их в переменные `film_name` (тип `string`) и `film_rating` (тип `float`) соответственно.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 1. Ищем карточки с актёрами (3 балла)
#
# Используя возможности библиотек `requests` и `bs4`, извлеките со страницы *Актеры и роли* (ссылка в `titr`) информацию об актёрах в «сыром» виде, в виде объектов `BeautifulSoup`. Для этого найдите все фрагменты кода HTML с информацией, которая хранится на карточке актёра, и сохраните их в список `act_info`.
#
# Для определённости – вот пример элемента списка `act_info`:
#
#     <div class="actor_details">
#     <div class="actor_film_descript" id="role_16801">
#     <div class="film_name"><a href="/kino/acter/w/sov/4484/bio/" itemprop="url" title="Лидия Федосеева-Шукшина"><strong itemprop="name">Лидия Федосеева-Шукшина</strong></a></div>
#     <div class="film_role">Королева Флора — <span class="film_main_role">главная роль</span></div>
#     <div class="film_role_descript">жена короля Теодора</div>
#     <div class="film_rating"><span id="role_rating_16801"></span></div>
#     </div>
#     <div class="actor_film_screens"><a href="/kino/movie/sov/4319/foto/a4484/1162854/" title="Лидия Федосеева-Шукшина"><img alt="Лидия Федосеева-Шукшина" class="actor_film_img" src="/acter/photo/4/8/4484/pv_1162854.jpg" title="Лидия Федосеева-Шукшина"/></a></div>
#     </div>
#
# Выберите только элементы с индексами от 0 до 33 включительно, сохраните изменения в том же списке. Если информация сгружена правильно, это все актёры без учета актёров дубляжа и каскадёров. Их труд очень ценен, особенно с учётом некоторых деталей съёмок, но для следующих задач нужен рейтинг, а его для актёров за кадром на сайте нет.

# %%
### YOUR CODE HERE ###

# %%
assert len(act_info) == 34, "Проверьте число элементов в списке"
assert str(type(act_info[0])) == "<class 'bs4.element.Tag'>", "Проверьте тип элементов, это должны быть объекты BeautifulSoup"

# %% [markdown]
# ### Задача 2. Выгружаем данные из карточек с актёрами (4 балла)
#
# Напишите функцию `get_personal()`, которая принимает на вход элемент списка `act_info` и возвращает список из следующих характеристик:
#
#   * id актёра (`role_16801` в примере выше);
#   * ФИО актёра (`Лидия Федосеева-Шукшина` в примере выше);
#   * роль (`Королева Флора` — главная роль в примере выше, пустая строка, если её нет);
#   * описание роли (`жена короля Теодора` в примере выше, пустая строка, если его нет).
#
# Примените эту функцию ко всем элементам списка `act_info` и создайте новый список списков такого вида:
#
#         [['role_16801', 'Лидия Федосеева-Шукшина', 'Королева Флора — главная роль', 'жена короля Теодора'],
#         ['role_16800', 'Вячеслав Невинный', 'Король Теодор — главная роль', ''],
#         ...]
#
# *Примечание.* Если роль/её описание не найдены, можете использовать конструкцию `try-except`, чтобы в случае ошибки сохранять просто пустую строку.
#
# Преобразуйте полученный список в датафрейм `main`, присвойте столбцам названия `id`, `name`, `role`, `desc`. Первые несколько строк датафрейма `main` для самопроверки:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>role</th>
#       <th>desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>role_16801</td>
#       <td>Лидия Федосеева-Шукшина</td>
#       <td>Королева Флора — главная роль</td>
#       <td>жена короля Теодора</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>role_16800</td>
#       <td>Вячеслав Невинный</td>
#       <td>Король Теодор — главная роль</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>role_16803</td>
#       <td>Игорь Красавин</td>
#       <td>Патрик — главная роль</td>
#       <td>воспитанник королевы</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>role_16802</td>
#       <td>Варвара Владимирова</td>
#       <td>Альбина</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %%
### YOUR CODE HERE ###

# %% [markdown]
# Тесты для проверки работы функции `get_personal()`:

# %%
assert type(get_personal(act_info[3])[0]) == str, "Проверьте, тип id, должна быть строка, а не целое число"
assert get_personal(act_info[3])[0] == 'role_16802', "Проверьте, что id не содержит лишнего текста и _"
assert get_personal(act_info[1])[-1] == '', "Проверьте, что в описание роли сохраняется пустая строка, если описание роли отсутствует"
assert get_personal(act_info[5])[-2] == 'Оттилия', "Проверьте, что название роли сохраняется верно и стоит на нужном месте в списке"
assert get_personal(act_info[9])[1] == 'Владимир Ставицкий', "Проверьте, что имя актера сохраняется верно и стоит на нужном месте в списке"
assert get_personal(act_info[14])[2] == '', "Проверьте, что в названии роли сохраняется пустая строка, если название роли отсутствует"

# %% [markdown]
# Тесты для проверки полученного датафрейма `main`:

# %%
assert list(main.columns) == ["id", "name", "role", "desc"], "Проверьте наличие названий столбцов в датафрейме и сами названия"
assert (main.dtypes.values == "object").sum() == 4, "Проверьте, что все столбцы текстовые (тип object)"

# %% [markdown]
# ### Задача 3. Добавляем информацию о лайках и дизлайках (1 балл)
#
# Информация о лайках и дизлайках, поставленных зарегистированными пользователями сайта актёрам, сыгравшим в этом фильме, хранится не в карточках актёров, а внутри кода JavaScript, который используется для отрисовки зелёных и красных кнопок рядом с фотографиями актёров. Это обусловлено тем, что информация об оценке актёров – динамическая, она регулярно обновляется и подставляется на эти кнопки с помощью функции на JavaScript, которую ранее написали разработчики.
#
# Выгрузить информацию из строки с кодом JavaScript можно, но для этого потребуются регулярные выражения и обработка JSON, поэтому из гуманистических соображений ниже приведён код для загрузки готовых данных из CSV-файла (по состоянию на 15.10.24):

# %%
import pandas as pd
rating = pd.read_csv("https://raw.githubusercontent.com/allatambov/PyAll24/refs/heads/main/kt_ratings.csv")

# %% [markdown]
# Объедините датафреймы `main` и `rating` по столбцу с id актёров и сохраните результат в датафрейм `kteatr` (этот код уже написан):

# %%
kteatr = main.merge(rating, on = "id")

# %% [markdown]
# Добавьте в датафрейм `kteatr` столбец `rating` со значениями разности между числом лайков и дизлайков для каждого актёра. Отсортируйте результаты по полученному рейтингу в порядке убывания и выведите результат на экран.
#
# **Подсказка:** все тот же метод `.sort_values()`.

# %%
### YOUR CODE HERE ###
